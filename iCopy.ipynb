# %% [markdown]
# <a href="https://colab.research.google.com/github/Nenokkadine/FClone-Bot/blob/master/iCopy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown <h3><b>←</b> Run this cell to install all required modules </h3>
# !sudo add-apt-repository ppa:deadsnakes/ppa -y
# !sudo apt update
# !sudo apt install unzip
# !sudo apt install python3.8
# !sudo apt-get install python3.8-venv
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 3
# !curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3 get-pip.py --force-reinstall
# !pip3 install -U pip
# !git clone https://github.com/Nenokkadine/FClone-Bot.git
# %cd /content/FClone-Bot
# !pip3 install -r requirements.txt
# !bash <(wget -qO- https://git.io/JJYE0)
from IPython.display import HTML, clear_output
clear_output()
print("Successfully Installed")

# %%
#@markdown <h3><b>←</b>Fill all the Vars and Run the cell</h3>
BOT_TOKEN = "" #@param {type:"string"}
USER_ID = "" #@param {type:"string"}
DB_CONNECT_METHOD ="mongodb+srv"#@param {type:"string"}
DB_ADDRESS = "icopybot.n8vl0.mongodb.net"#@param {type:"string"}
DB_PORT="27017"#@param {type:"string"}
DB_NAME="iCopy"#@param {type:"string"}
DB_USERNAME=""#@param {type:"string"}
DB_PASS=""#@param {type:"string"}
LANGUAGE="eng"#@param {type:"string"}
CLONER="fclone"#@param {type:"string"}
OPTION="copy"#@param {type:"string"}
RCLONE_RMT="iCopy"#@param {type:"string"}
PARALLEL_CHECKERS="250"#@param {type:"string"}
PARALLEL_TRANSFERS="250"#@param {type:"string"}
MIN_SLEEP="1ms"#@param {type:"string"}
SA_INIT_FILE="sample.json"#@param {type:"string"}
SA_ZIP_URL="sample.com/sa.zip"#@param {type:"string"}
TEAM_DRIVE_ID=""#@param {type:"string"}
RUN_ARGS="['-P', '--ignore-checksum' , '--stats=1s', '--log-level=DEBUG', '--log-file=/content/icopy_cloner_debug.log']"
SA_PATH = "/content/FClone-Bot/iCopy/accounts"
import os
os.environ['RCLONE_CONFIG']="/content/FClone-Bot/iCopy/config/rclone.conf"
# %cd /content/FClone-Bot/iCopy/config/
# !echo -e "[tg]\n"token = "\"$BOT_TOKEN\"\n"usr_id = "\"$USER_ID\"\n[database]\n"db_connect_method = "\"$DB_CONNECT_METHOD\"\n"db_addr = "\"$DB_ADDRESS\"\n"db_port = "$DB_PORT""\n"db_name = "\"$DB_NAME\"\n"db_user = "\"$DB_USERNAME\"\n"db_passwd = "\"$DB_PASS\"\n[general]\n"language = "\"$LANGUAGE\" \n"cloner = "\"$CLONER\"\n"option = "\"$OPTION\" \n"remote = "\"$RCLONE_RMT\"\n"parallel_c = "\"$PARALLEL_CHECKERS\"\n"parallel_t = "\"$PARALLEL_TRANSFERS\"\n"min_sleep = "\"$MIN_SLEEP\"\n"sa_path = "\"$SA_PATH\"\nrun_args = $RUN_ARGS" >> conf.toml
# !echo "[$RCLONE_RMT]\ntype = drive\nscope = drive\n"service_account_file = /app/iCopy/accounts/$SA_INIT_FILE"\n"service_account_file_path = $SA_PATH"\n"team_drive = $FOLDER_ID"" >> rclone.conf
# %cd ..
# !wget --no-check-certificate -q $SA_ZIP_URL -O accounts.zip
# !unzip -qq accounts.zip -d /content/FClone-Bot/iCopy/

# %%
#@markdown <h3><b>←</b>Run this cell to start the Bot</h3>
# %cd /content/FClone-Bot/iCopy/
# !chmod 777 Bot.py
# !python3 Bot.py
